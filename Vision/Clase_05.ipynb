# %% [markdown]
# # Inteligencia Artificial

# %% [markdown]
# - la IA es una ciencia que intenta crear programas para máquinas que imiten el comportamiento y la comprensión humana.
# - Intenta crear máquinas y/o programas para automatizar tareas que requieran de comportamiento inteligente.
# - Estas máquinas y/o programas se denominan agentes.
# - Se denomina IA a la rama de la ciencia informática dedicada al desarrollo de agentes racionales no vivos.
# - Un agente es cualquier cosa capaz de percibir su entorno (recibir entradas), procesar tales percepciones y actuar en su entorno (proporcionar salidas).

# %% [markdown]
# ## Machine learning
#
# - Automatización
# - Mejora de la precisión
# - Solucionar problemas existentes que requieren muchos ajustes o largas listas de reglas.
# - Análisis de grandes cantidades de datos.
# -

# %% [markdown]
# Machine learning utiliza datos y produce un programa para realizar una tarea.

# %% [markdown]
# ### Desafíos del ML
# - Acceso y exploración de datos:
#   - Diversidad en los datos (numericos, señales, imagenes, texto, data no tabular)
# - Preprocesamiento de datos.
# - Despliege de modelos predictivos:
#   - Probar con varios modelos hasta encontrar el mejor.
#   - Evitar el overfitting

# %% [markdown]
# ### Mapa general de ML:
# - Aprendizaje supervisado: Agrupa e interpreta los datos solo con las entradas.
#   - Clustering
# - Aprendizaje no supervisado: Desarrolla modelos predictivos basados en las entradas y salidas.
#   - Clasificación:
#     La salida es una opción entre las clases (Verdadero, Falso / Rojo, Verde, Negro)
#   - Regresión:
#     La salida es un número real (Temperatura, Precios nuevos, etc.)

# %% [markdown]
# ### Regresión lineal

# %% [markdown]
# Ajustamos nuestros datos a una linea recta:
# $$ y = \beta_0 + \beta x + \epsilon  $$
# Dónde:
# - $\epsilon$ es el residuo
# - $\beta$ es la pendiente
# - $\beta_0$ es la intersección con el eje $y$
